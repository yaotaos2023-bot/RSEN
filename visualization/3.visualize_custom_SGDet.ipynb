# %%
import torch
import json
import h5py
import random
import numpy as np
from matplotlib.pyplot import imshow
from PIL import Image, ImageDraw

# %%
# load the following to files from DETECTED_SGG_DIR
custom_prediction = json.load(open('C:/Users/21185/Desktop/MyImages/custom_prediction.json'))
custom_data_info = json.load(open('C:/Users/21185/Desktop/MyImages/custom_data_info.json'))

# %%
def draw_single_box(pic, box, color='red', draw_info=None):
    draw = ImageDraw.Draw(pic)
    x1,y1,x2,y2 = int(box[0]), int(box[1]), int(box[2]), int(box[3])
    draw.rectangle(((x1, y1), (x2, y2)), outline=color)
    if draw_info:
        draw.rectangle(((x1, y1), (x1+50, y1+10)), fill=color)
        info = draw_info
        draw.text((x1, y1), info)
        
def print_list(name, input_list, scores=None):
    for i, item in enumerate(input_list):
        if scores == None:
            print(name + ' ' + str(i) + ': ' + str(item))
        else:
            print(name + ' ' + str(i) + ': ' + str(item) + '; score: ' + str(scores[i]))
    
def draw_image(img_path, boxes, box_labels, rel_labels, box_scores=None, rel_scores=None):
    size = get_size(Image.open(img_path).size)
    pic = Image.open(img_path).resize(size)
    num_obj = len(boxes)
    for i in range(num_obj):
        info = str(i) + '_' + box_labels[i]
        draw_single_box(pic, boxes[i], draw_info=info)
    display(pic)
    print('*' * 50)
    print_list('box_labels', box_labels, box_scores)
    print('*' * 50)
    print_list('rel_labels', rel_labels, rel_scores)
    
    return None

def get_size(image_size):
    min_size = 600
    max_size = 1000
    w, h = image_size
    size = min_size
    if max_size is not None:
        min_original_size = float(min((w, h)))
        max_original_size = float(max((w, h)))
        if max_original_size / min_original_size * size > max_size:
            size = int(round(max_size * min_original_size / max_original_size))
    if (w <= h and w == size) or (h <= w and h == size):
        return (w, h)
    if w < h:
        ow = size
        oh = int(size * h / w)
    else:
        oh = size
        ow = int(size * w / h)
    return (ow, oh)

# %%
# parameters
image_idx = 2
box_topk = 30 # select top k bounding boxes
rel_topk = 20 # select top k relationships
ind_to_classes = custom_data_info['ind_to_classes']
ind_to_predicates = custom_data_info['ind_to_predicates']

# %%
image_path = custom_data_info['idx_to_files'][image_idx]
boxes = custom_prediction[str(image_idx)]['bbox'][:box_topk]
box_labels = custom_prediction[str(image_idx)]['bbox_labels'][:box_topk]
box_scores = custom_prediction[str(image_idx)]['bbox_scores'][:box_topk]
all_rel_labels = custom_prediction[str(image_idx)]['rel_labels']
all_rel_scores = custom_prediction[str(image_idx)]['rel_scores']
all_rel_pairs = custom_prediction[str(image_idx)]['rel_pairs']

for i in range(len(box_labels)):
    box_labels[i] = ind_to_classes[box_labels[i]]

rel_labels = []
rel_scores = []
for i in range(len(all_rel_pairs)):
    if all_rel_pairs[i][0] < box_topk and all_rel_pairs[i][1] < box_topk:
        rel_scores.append(all_rel_scores[i])
        label = str(all_rel_pairs[i][0]) + '_' + box_labels[all_rel_pairs[i][0]] + ' => ' + ind_to_predicates[all_rel_labels[i]] + ' => ' + str(all_rel_pairs[i][1]) + '_' + box_labels[all_rel_pairs[i][1]]
        rel_labels.append(label)

rel_labels = rel_labels[:rel_topk]
rel_scores = rel_scores[:rel_topk]

draw_image(image_path, boxes, box_labels, rel_labels, box_scores=box_scores, rel_scores=rel_scores)
# Out:
# <PIL.Image.Image image mode=RGB size=600x800>
# **************************************************
# box_labels 0: bowl; score: 0.8536462783813477
# box_labels 1: bowl; score: 0.8049878478050232
# box_labels 2: glass; score: 0.6585736274719238
# box_labels 3: table; score: 0.6328372955322266
# box_labels 4: bowl; score: 0.6102696061134338
# box_labels 5: hand; score: 0.5207203030586243
# box_labels 6: glass; score: 0.5151903033256531
# box_labels 7: chair; score: 0.49519720673561096
# box_labels 8: woman; score: 0.41293570399284363
# box_labels 9: table; score: 0.3576975166797638
# box_labels 10: food; score: 0.3458493947982788
# box_labels 11: man; score: 0.34217047691345215
# box_labels 12: window; score: 0.30962252616882324
# box_labels 13: face; score: 0.28968384861946106
# box_labels 14: man; score: 0.27113452553749084
# box_labels 15: woman; score: 0.2587510049343109
# box_labels 16: shirt; score: 0.2516283094882965
# box_labels 17: chair; score: 0.22493092715740204
# box_labels 18: shirt; score: 0.2111278772354126
# box_labels 19: food; score: 0.20842207968235016
# box_labels 20: chair; score: 0.20767271518707275
# box_labels 21: bowl; score: 0.18330465257167816
# box_labels 22: food; score: 0.1639893800020218
# box_labels 23: nose; score: 0.1590023636817932
# box_labels 24: plate; score: 0.1482953131198883
# box_labels 25: hair; score: 0.14174163341522217
# box_labels 26: mouth; score: 0.12736058235168457
# box_labels 27: person; score: 0.12610182166099548
# box_labels 28: head; score: 0.1253998577594757
# box_labels 29: plate; score: 0.12331508845090866
# **************************************************
# rel_labels 0: 12_window => behind => 14_man; score: 0.9260859489440918
# rel_labels 1: 20_chair => at => 9_table; score: 0.8885427117347717
# rel_labels 2: 14_man => at => 9_table; score: 0.8757709264755249
# rel_labels 3: 22_food => in => 21_bowl; score: 0.8743534088134766
# rel_labels 4: 7_chair => at => 9_table; score: 0.8703652620315552
# rel_labels 5: 14_man => at => 3_table; score: 0.8637003302574158
# rel_labels 6: 17_chair => at => 9_table; score: 0.8543673753738403
# rel_labels 7: 11_man => at => 9_table; score: 0.8488407731056213
# rel_labels 8: 8_woman => at => 9_table; score: 0.8271822929382324
# rel_labels 9: 5_hand => holding => 0_bowl; score: 0.8247573375701904
# rel_labels 10: 27_person => watching => 14_man; score: 0.8238546848297119
# rel_labels 11: 14_man => has => 23_nose; score: 0.8236458897590637
# rel_labels 12: 20_chair => at => 3_table; score: 0.815448522567749
# rel_labels 13: 8_woman => watching => 14_man; score: 0.8108559250831604
# rel_labels 14: 22_food => in => 1_bowl; score: 0.8101598620414734
# rel_labels 15: 10_food => in => 21_bowl; score: 0.8079981207847595
# rel_labels 16: 14_man => has => 13_face; score: 0.8003153204917908
# rel_labels 17: 27_person => at => 9_table; score: 0.7971109747886658
# rel_labels 18: 27_person => watching => 11_man; score: 0.7953318357467651
# rel_labels 19: 14_man => has => 26_mouth; score: 0.7943043112754822
